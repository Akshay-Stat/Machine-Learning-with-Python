# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-Stat/Machine-Learning-with-Python/blob/master/Data_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Steps involved in EDA (Exploratory Data Analysis)
#
# Step 1- Understand the data
#
# Step 2- Clean the data
#
# Step 3- Analyze the relationship between the variables

# %% [markdown]
# **To start with I am going to import few important libraries and load data set.**

# %%
import numpy as np                        # linear algebra
import pandas as pd                        # Data Processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt       # We can plot our data and make a graphical representation of it
import seaborn as sns                     # helps to visualize the data
from subprocess import check_output
import warnings                              # no warnings will be printed from now on
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("bank.csv", sep = ';')   # Import data to use pandas library
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ### Step-1. Understand the data

# %%
display(data)        # Display the DataFrame
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# The “.head()” function of pandas library by default gives you the top five rows and similarly the “.tail()”  function will give you the last five rows.

# %%
data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
data.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %% [markdown]
#  “.info()” gives you information about the data. The above data has only float and integer values and no missing value.

# %%
data.columns  # gives the list of the column (header) names.
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# It gives you various columns name in the data.

# %%
data.index           # Returns the list of the index
# Out:
# RangeIndex(start=0, stop=4521, step=1)

# %%
data.shape      # Shows the dimension of the dataframe
# Out:
# (4521, 17)

# %% [markdown]
# “.shape” command gives you the total number of columns and rows present in the data.

# %%
data.nunique()    # Check unique values
# Out:
# age            67
# job            12
# marital         3
# education       4
# default         2
# balance      2353
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration      875
# campaign       32
# pdays         292
# previous       24
# poutcome        4
# y               2
# dtype: int64

# %% [markdown]
# Counts the unique value in the data set.

# %%
data['y'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %% [markdown]
# This function returns the count, mean, standard deviation, minimum and maximum values and the quantiles of the data. In the above data the mean value is less than the median value of each column. There is also notably large difference between the 75% and max value in few predictors.

# %%
Count_No = len(data[data.y == 'no'])                               # To find the answer in percentage of 'yes' and 'no'  
Count_Yes = len(data[data.y == 'yes'])
print('Percentage of "No": {:.3f}%'. format((Count_No/(len(data.y))*100)))
print('Percentage of "Yes": {:.3f}%'. format((Count_Yes/(len(data.y))*100)))
# Out:
# Percentage of "No": 88.476%
# Percentage of "Yes": 11.524%

# %%
TC_y = len(data.y)         # Total Count of y
TC_y
# Out:
# 4521

# %%
count_no = len(data[data['y']=='no'])                         # 
print ('\n No Count :',count_no)
count_yes = len(data[data['y']=='yes'])
print ('\n Yes Count: ' ,count_yes)
# Out:
#  No Count : 4000
#
#  Yes Count:  521

# %%
N1 = print('Percentage of "No" :  ', count_no/ TC_y*100, '%')
N1
Y1 = print('Percentage of "Yes" :  ', count_yes/ TC_y*100, '%')
Y1
# Out:
# Percentage of "No" :   88.47600088476001 %
# Percentage of "Yes" :   11.523999115239992 %

# %%
## Count the occurance of unique values in class column
data2 = data.y.value_counts(); data2
# Out:
# no     4000
# yes     521
# Name: y, dtype: int64

# %% [markdown]
# ### 2. Data Cleaning

# %%
#Verifying null values
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='OrRd_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### There is no missing values

# %%
data.isnull().sum()         # List down missing data in a data set
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
data.isnull().any()             # Identify the missing values in a whole dataframe
# Out:
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# y            False
# dtype: bool

# %%
data.isnull().values                # False if any value in DataFrame is not NaN or None
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %% [markdown]
# This function basically checks for the null value in the data set. There are no null values in this data.

# %% [markdown]
# ### Define X and y

# %%
X = data.drop(['y','job','marital', 'education', 'contact',                                          # Drop some parameter in data
             'housing', 'loan', 'day', 'month', 'poutcome' ], axis=1)
#X

# %%
y = data['y']                                                                     # 'y' parameter stored in y
#y

# %% [markdown]
# ### Get Dummies Values

# %%
X = pd.get_dummies(X,drop_first=True)
y = pd.get_dummies(y,drop_first=True)

# %%
X.columns
X = X.rename(columns = {'default_yes': 'default'})
y.columns
y = y.rename(columns= {'yes': 'y'})

# %%
data_1=pd.concat([X,y],axis=1)
data_1
# Out:
#       age  balance  duration  campaign  pdays  previous  default  y
# 0      30     1787        79         1     -1         0        0  0
# 1      33     4789       220         1    339         4        0  0
# 2      35     1350       185         1    330         1        0  0
# 3      30     1476       199         4     -1         0        0  0
# 4      59        0       226         1     -1         0        0  0
# ...   ...      ...       ...       ...    ...       ...      ... ..
# 4516   33     -333       329         5     -1         0        0  0
# 4517   57    -3313       153         1     -1         0        1  0
# 4518   57      295       151        11     -1         0        0  0
# 4519   28     1137       129         4    211         3        0  0
# 4520   44     1136       345         2    249         7        0  0
#
# [4521 rows x 8 columns]

# %% [markdown]
# ### Step-3. Visualization of the Data and Finding the Relationship between the Variables.
#
# Python has a visualization library, Seaborn which build on top of matplotlib. It provides very attractive statistical graphs in order to perform both Univariate and Multivariate analysis.
#
# In order to use regression for the modelling, it is necessary to remove correlated variables to improve the model. We can do that by using pandas “.corr()” and can also the visualize the correlation matrix using heatmap.

# %% [markdown]
# ### Relationship Analysis

# %%
corelation = data_1.corr()
corelation
# Out:
#                age   balance  duration  campaign     pdays  previous  \
# age       1.000000  0.083820 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.015950 -0.009976  0.009437  0.026196
# duration -0.002367 -0.015950  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196  0.018080 -0.067833  0.577562  1.000000
# default  -0.017885 -0.070886 -0.011615 -0.012348 -0.026317 -0.026656
# y         0.045092  0.017905  0.401118 -0.061147  0.104087  0.116714
#
#            default         y
# age      -0.017885  0.045092
# balance  -0.070886  0.017905
# duration -0.011615  0.401118
# campaign -0.012348 -0.061147
# pdays    -0.026317  0.104087
# previous -0.026656  0.116714
# default   1.000000  0.001303
# y         0.001303  1.000000

# %%
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The dark shades represent a positive correlation and a lighter shade represents negative. It’s a good to remove correlated variable in feature selection.

# %% [markdown]
# Another way of analyzing numerical data would be to use box plots. Box plot shows us the median of the data, which represents where the middle data point is. The upper and lower quartiles represent the 75 and 25 percentiles of the data respectively. The upper and lower extremes show us the extreme ends of the distribution of our data.

# %%
plt.boxplot(data_1)
plt.show()

# %% [markdown]
# ### Visualising Data
#
# Those plotting functions pyplot.hist, seaborn.countplot and seaborn.displot are all helper tools to plot the frequency of a single variable. Depending on the nature of this variable they might be more or less suitable for visualization.

# %% [markdown]
# ### Histogram
#
# Histogram shows us the frequency distribution of a variable.

# %%
data_1.hist(figsize=(15,15)) 
plt.tight_layout()
plt.show()

# %%
pd.crosstab(data.age,data.y).plot(kind="bar",figsize=(20,6))
plt.title('Client Subscribed Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
pd.crosstab(data.marital,data.y).plot(kind="bar",figsize=(15,6),color=['#1CA53B','#AA1111' ])
plt.title('Client Subscribed Frequency for Maritial')
plt.xlabel('marital')
plt.xticks(rotation=0)
plt.legend(["Haven't Subscribed", "Have Subscribed"])
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(x=data.age[data.y=='yes'], y=data.duration[(data.y=='yes')], c="red")
plt.scatter(x=data.age[data.y=='no'], y=data.duration[(data.y=='no')])
plt.legend(["Have Subscribed", "Haven't Subscribed"])
plt.xlabel("Age")
plt.ylabel("Duration")
plt.show()

# %%
sns.pairplot(data=data, hue='y')

# %%
sns.pairplot(data=data, hue='y', vars= ['age', 'balance', 'duration'])

# %%
sns.countplot(x='y', data=data, label='Count')
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>

# %%
sns.scatterplot(x='age', y='balance', hue='y', data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='balance'>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data=data_1.corr(), annot=True, cmap='Wistia')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(data.age, bins = 20)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(data.balance, bins = 20)
# Out:
# <AxesSubplot:xlabel='balance', ylabel='Density'>

# %%
sns.distplot(data.duration, bins = 20)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Density'>

# %%
for ad in data_1.columns[:-1]:
    print(ad)
    s=data_1[ad]
    plt_1=sns.distplot(s,color='purple')
    plt.title(ad,loc='right')

    plt.show()
# Out:
# age
# balance
# duration
# campaign
# pdays
# previous
# default

# %%
#Age group
bins = range(0, 100, 10)
ax = sns.distplot(data.age [data.y == 'yes'],
              color='red', kde=False, bins=bins, label='Have Subscribed')
sns.distplot(data.age[data.y=='no'],
         ax=ax,  # Overplots on first plot
         color='orange', kde=False, bins=bins, label="Haven't Not Subscribed")
plt.legend()
plt.show()
